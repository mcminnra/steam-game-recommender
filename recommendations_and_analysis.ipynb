# %%
import shap
from sgr import recommend_games

# %%
model, output_df, shap_values, X = recommend_games()
# Out:
# ::  Getting Steam user review data and gathering game metadata...
#              Rank                          Game Platform  \
# Steam AppID
# 252950        1.0                 Rocket League       PC
# 427520        2.0                      Factorio       PC
# 570940        3.0         Dark Souls Remastered       PC
# 570           4.0                        Dota 2       PC
# 620           5.0                      Portal 2       PC
# 1172380       6.0  Star Wars Jedi: Fallen Order       PC
# 489830        7.0   The Elder Scrolls V: Skyrim       PC
# 646570        8.0                Slay The Spire       PC
# 1085660       9.0                     Destiny 2       PC
# 526870       10.0                  Satisfactory       PC
# 1046930      11.0               Dota Underlords       PC
# 431240       12.0        Golf With Your Friends       PC
# 268500       13.0                        XCOM 2       PC
# 480490       14.0                          Prey       PC
# ...

# %%
shap.summary_plot(shap_values, X)

# %%
shap.dependence_plot("Strategy", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("All Percent", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Indie", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Singleplayer", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Exploration", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("First-Person", shap_values, X, interaction_index=None)
