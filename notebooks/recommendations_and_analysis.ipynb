# %%
import sys
sys.path.append("..")

import shap
from sgr import recommend_games

# %%
model, output_df, shap_values, X = recommend_games()
# Out:
#  Getting train Steam Game recent and all review percentages:   0%|          | 0/39 [00:00<?, ?it/s]
# ::  Getting Steam user review data and gathering game metadata...
#              Rank                                         Game Platform  \
# Steam AppID
# 292030        1.0                     The Witcher 3: Wild Hunt       PC
# 570940        2.0                        Dark Souls Remastered       PC
# 427520        3.0                                     Factorio       PC
# 252950        4.0                                Rocket League       PC
# 367520        5.0                                Hollow Knight       PC
# 620           6.0                                     Portal 2       PC
# 335300        7.0      Dark Souls II: Scholar of the First Sin       PC
# 1085660       8.0                                    Destiny 2       PC
# 570           9.0                                       DOTA 2       PC
# ...

# %%
shap.summary_plot(shap_values, X)

# %%
shap.dependence_plot("All Percent", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Multiplayer", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Simulation", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Great Soundtrack", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Strategy", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("Sci-fi", shap_values, X, interaction_index=None)

# %%
shap.dependence_plot("FPS", shap_values, X, interaction_index=None)
